# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)

# %%
#getting the basic description about the data

# %%
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
pd.isnull(boston_df)
# Out:
#      Unnamed: 0   CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS  \
# 0         False  False  False  False  False  False  False  False  False
# 1         False  False  False  False  False  False  False  False  False
# 2         False  False  False  False  False  False  False  False  False
# 3         False  False  False  False  False  False  False  False  False
# 4         False  False  False  False  False  False  False  False  False
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501       False  False  False  False  False  False  False  False  False
# 502       False  False  False  False  False  False  False  False  False
# 503       False  False  False  False  False  False  False  False  False
# 504       False  False  False  False  False  False  False  False  False
# 505       False  False  False  False  False  False  False  False  False
#
#        RAD    TAX  PTRATIO  LSTAT   MEDV
# 0    False  False    False  False  False
# ...

# %%
boston_df.hist(figsize=[20,20])
plt.show()

# %%
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# 3  222.0     18.7   2.94  33.4
# 4  222.0     18.7   5.33  36.2

# %%
sns.boxplot(x=boston_df['MEDV'])
# Question no 1
# Out:
# <AxesSubplot:xlabel='MEDV'>

# %%
#The median is  $22000 
cols=['MEDV','CHAS']
chas=boston_df[cols]
chas=chas.groupby('CHAS').count()
boston_df.CHAS.value_counts().plot(kind='bar')
plt.ylabel('CHAS count')
chas
#Question no 2
# Out:
#       MEDV
# CHAS
# 0.0    471
# 1.0     35

# %%
colns=['AGE','MEDV']
Age_cat=boston_df[colns]

# %%
age1=Age_cat[(Age_cat.AGE<=35)]
age2=Age_cat[(Age_cat.AGE>35)&(Age_cat.AGE<70)]
age3=Age_cat[(Age_cat.AGE>=35)]
age1
# Out:
#       AGE  MEDV
# 16   29.3  23.1
# 38   30.2  24.7
# 39   21.8  30.8
# 40   15.8  34.9
# 41    2.9  26.6
# ..    ...   ...
# 349  34.5  26.6
# 352  18.5  18.6
# 354  21.9  18.2
# 355  19.5  20.6
# 495  28.8  23.1
#
# [91 rows x 2 columns]

# %%
fig = plt.figure(figsize =(10, 7))
data=[age1['MEDV'],age2['MEDV'],age3['MEDV']]
s=['Less than 35','Between 35 and 70','Greater than 70']
plt.boxplot(data,labels=s)
plt.title("MEDV variable vs the AGE variable")
plt.show()
# Question no 3

# %%
#Median values of the owner occupied houses decreases with age

# %%
boston_df.columns
# Out:
# Index(['Unnamed: 0', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
#        'RAD', 'TAX', 'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
sns.scatterplot(x='NOX',y='INDUS',data=boston_df)
#Question no 4
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='INDUS'>

# %%
# the nitrous oxide concentration have postive correlation with the proportion of not retail business acres per town

# %%
boston_df.hist(column='PTRATIO', figsize=[12, 8], bins=15)
plt.show()
#Question no 5

# %%
# Pupils to teacher ratio histogram

# %%
import scipy.stats as stats
# null hypothesis : The average values of houses bounded by charles river and not bounded by charles river are same

# %%
stats.ttest_ind(boston_df['MEDV'][boston_df['CHAS']==1],boston_df['MEDV'][boston_df['CHAS']==0])
# Out:
# Ttest_indResult(statistic=3.996437466090509, pvalue=7.390623170519905e-05)

# %%
# The p-value is less than 0.005. there is a significant difference in median value of houses bounded by the Charles river. Reject the null hypothesis

# %%
CHAS_avg1=boston_df[(boston_df.CHAS==1)].MEDV.mean()

# %%
sns.barplot(x='CHAS',y='MEDV',data=boston_df)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='MEDV'>

# %%
# Conclusion:The p-value is less than 0.005. there is a significant difference in median value of houses bounded by the Charles river. Reject the null hypothesis

# %%
stats.f_oneway(age1['MEDV'],age2['MEDV'],age3['MEDV'])
# Out:
# F_onewayResult(statistic=25.095358036920675, pvalue=3.2582287576927045e-11)

# %%
#Null hypothesis: Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE) (ANOVA) are same
#conclusion: p-value is less than 0.05. Reject Null hypothesis
#there  is a significant difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)

# %%
import scipy
from scipy import stats

# %%
 r,p = scipy.stats.pearsonr(boston_df['NOX'],boston_df['INDUS'])

# %%
r
# Out:
# 0.7636514469209151

# %%
#conclusion: Ther is a relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.
# As the value is close to 1 the there is a direct relationship between both the variables
